# %%
#importing all necessary libraries for data wrangling and analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("amz_com-ecommerce_sample.csv", encoding= 'unicode_escape')
df1.head(2)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#                           product_name  \
# 0  Alisha Solid Women's Cycling Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
#
#    retail_price  discounted_price  \
# 0           982               438
# 1         32143             29121
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# ...

# %%
df1.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
df2 = pd.read_csv("flipkart_com-ecommerce_sample.csv",encoding ='unicode_escape')
df2.head(2)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#                           product_name  \
# 0  Alisha Solid Women's Cycling Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
# 1       32157.0           22646.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# ...

# %%
df2.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
df1 = pd.DataFrame(df1)

# %%
df2 = pd.DataFrame(df2)

# %%
merged_df = df2.merge(df1, how = 'inner', on = ['pid'])
merged_df.head(2)
# Out:
#                           uniq_id_x          crawl_timestamp_x  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                        product_url_x  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#                         product_name_x  \
# 0  Alisha Solid Women's Cycling Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed
#
#                              product_category_tree_x               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
#
#    retail_price_x  discounted_price_x  \
# 0           999.0               379.0
# 1         32157.0             22646.0
#
#                                              image_x  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...
# ...

# %%
merged_df.columns
# Out:
# Index(['uniq_id_x', 'crawl_timestamp_x', 'product_url_x',
#        'Product name in Flipkart', 'product_category_tree_x', 'pid',
#        'Retail Price in Flipkart', 'Discounted Price in Flipkart', 'image_x',
#        'is_fk_advantage_product_x', 'description_x', 'product_rating_x',
#        'overall_rating_x', 'brand_x', 'product_specifications_x', 'uniq_id_y',
#        'crawl_timestamp_y', 'product_url_y', 'product_name_y',
#        'product_category_tree_y', 'retail_price_y', 'discounted_price_y',
#        'image_y', 'is_fk_advantage_product_y', 'description_y',
#        'product_rating_y', 'overall_rating_y', 'brand_y',
#        'product_specifications_y'],
#       dtype='object')

# %%
merged_df.rename(columns = {'product_name_x':'Product name in Flipkart','retail_price_x' : 'Retail Price in Flipkart','discounted_price_x' : 'Discounted Price in Flipkart','product_name_y':'Product name in Amazon','retail_price_y':'Retail Price in Amazon','discounted_price_y':'Discounted Price in Amazon'}, inplace = True)
merged_df.head(2)
# Out:
#                           uniq_id_x          crawl_timestamp_x  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                        product_url_x  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#               Product name in Flipkart  \
# 0  Alisha Solid Women's Cycling Shorts
# 1  FabHomeDecor Fabric Double Sofa Bed
#
#                              product_category_tree_x               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
#
#    Retail Price in Flipkart  Discounted Price in Flipkart  \
# 0                     999.0                         379.0
# 1                   32157.0                       22646.0
#
#                                              image_x  \
# ...

# %%
# final result 
merged_df.filter(items=['Product name in Flipkart', 'Retail Price in Flipkart','Discounted Price in Flipkart','Product name in Amazon','Retail Price in Amazon','Discounted Price in Amazon'], axis=1)
# Out:
#                       Product name in Flipkart  Retail Price in Flipkart  \
# 0          Alisha Solid Women's Cycling Shorts                     999.0
# 1          FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                                   AW Bellies                     999.0
# 3          Alisha Solid Women's Cycling Shorts                     699.0
# 4        Sicons All Purpose Arnica Dog Shampoo                     220.0
# ...                                        ...                       ...
# 19999           WallDesign Small Vinyl Sticker                    1500.0
# 20000  Wallmantra Large Vinyl Stickers Sticker                    1429.0
# 20001  Elite Collection Medium Acrylic Sticker                    1299.0
# 20002  Elite Collection Medium Acrylic Sticker                    1499.0
# 20003  Elite Collection Medium Acrylic Sticker                    1499.0
#
#        Discounted Price in Flipkart                   Product name in Amazon  \
# ...

# %% [markdown]
# # 2nd approach using Datacompy

# %%
pip install datacompy

# %%
import datacompy

# %%
compare = datacompy.Compare(df1, df2, join_columns='product_name',abs_tol=0.0001,rel_tol=0,df1_name='amazon',df2_name='flipkart')
compare.matches(ignore_extra_columns = False)
print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns   Rows
# 0    amazon       15  20000
# 1  flipkart       15  20000
#
# Column Summary
# --------------
#
# Number of columns in common: 15
# Number of columns in amazon but not in flipkart: 0
# Number of columns in flipkart but not in amazon: 0
#
# Row Summary
# -----------
#
# Matched on: product_name
# Any duplicates on match values: Yes
# Absolute Tolerance: 0.0001
# Relative Tolerance: 0
# Number of rows in common: 16,555
# Number of rows in amazon but not in flipkart: 3,445
# Number of rows in flipkart but not in amazon: 3,445
#
# Number of rows with some compared columns unequal: 16,555
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 13
# Number of columns compared with all values equal: 2
# Total number of values which compare unequal: 33,183
#
# ...
